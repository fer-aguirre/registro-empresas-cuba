# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/registro_empresas.xlsx', index_col=None, sheet_name='empresas', 
                    converters={'Fecha de la resolución': str, 
                                'Fecha Gaceta': str,
                                'No. de Resolución': str})

# %%
df_columns = list(df.columns)
df_columns
# Out:
# ['ORDEN',
#  'Nombre de la empresa extranjera',
#  'Nombre limpio definitivo',
#  'Nombre limpio viejo',
#  'Nombre del agente/representante cubano',
#  ' ',
#  ' .1',
#  'Tipo',
#  'Objeto de la resolución',
#  'País casa matriz del agente',
#  'País casa matriz',
#  'Representante en Cuba',
#  'Perfil',
#  'Prohibición de importar exportar, mayorismo y distribución mercancías ',
#  'Objeto',
#  'Anexo 1',
#  'Tipo de trámite',
#  'Resultado',
#  'Causa de denegación',
#  'Fecha de la resolución',
#  'Firmante nombre',
#  'Firmante cargo',
#  'Código resolución',
#  'No. de Resolución',
#  'Fecha Gaceta',
#  'Código gaceta',
#  'Link sitio gaceta',
#  'Link Drive PI']

# %%
# Define list of selection options and sort alphabetically
empresas = df['Nombre limpio definitivo'].drop_duplicates().to_list()
empresas.sort()
empresas
# Out:
# ['3437558 CANADA INC. (CORSAN GROUP)',
#  '3L INTERNACIONAL, S.A.',
#  '510172 ONTARIO LIMITED',
#  'A.E.E. ZARUBEZHTSVETMET',
#  'A.E.E. ZARUBEZHTSVETMET, S.A.',
#  'A.M. ELETTRONICA, S.R.L.',
#  'AAD TRADING GMBH',
#  'AB SANDVIK INTERNATIONAL',
#  'ABANICOS FOLGADO, S.L.',
#  'ABASTECEDORA INDUSTRIAL GARVA, S.A. DE C.V.',
#  'ABC AEROLÍNEAS, S.A. DE C.V.',
#  'ABENSA, S.A.',
#  'ABRASIVOS MENDIOLA, S.L.',
#  'ACANDO SHIPPING CO., LTD.',
#  'ACCESORIOS VILLA, S.L.',
#  'ACEMEX MANAGEMENT COMPANY LIMITED',
#  'ACEROS LST BILBAO, S.L.',
#  'ACHSE LATEINAMERIKA GMBH',
#  'ACTIVEWEAR VALERIO, S.L.',
#  'ADIDAS LATIN AMERICA, S.A.',
#  'AEROFLOT - AEROLÍNEAS RUSAS',
#  'AEROFLOT OAO - LÍNEAS AÉREAS DE RUSIA',
#  'AEROVÍAS DE MÉXICO, S.A. DE C.V.',
#  'AEROVÍAS DEL CONTINENTE AMERICANO, S.A. (AVIANCA)',
#  'AGEM, AUXILIAR GENERAL DE ELECTROMEDICINA, S.A.',
#  'AGENCIA MARÍTIMA MAPOR, S.A.',
#  'AGENCIA MARÍTIMA PÉREZ, S.A.',
#  'AGENCIA MARÍTIMA TAÍNA, S.A.',
#  'AGENCIA PARA EL DESARROLLO DE LA COLABORACIÓN INTERNACIONAL (ADCI)',
#  'AGOSTINI GMBH',
#  'AGRIA, S.A.',
#  'AGROMASHINVEST, S.R.L.',
#  'AINAIR, S.L.',
#  'AIR BERLIN PLC & CO. LUFTVERKEHRS KG.',
#  'AIR CANADA',
#  'AIR CARAIBES, S.A.',
#  'AIR CHINA LIMITED',
#  'AIR EUROPA LÍNEAS AÉREAS, S.A.',
#  'AIR ITALY, S.P.A.',
#  'AIR TECNIA, S.A. DE C.V.',
#  'AIR TRANSAT A.T. INC.',
#  'AIRFRANCE - KLM',
#  'AKBAR, S.R.L.',
#  'ALCATEL-LUCENT CENTRO CARIBBEAN HOLDING LIMITED',
#  'ALCATEL-LUCENT TRADE INTERNATIONAL, A.G.',
#  'ALCON-3, S.L.',
#  'ALDAKETA IMPORT-EXPORT, S.A.',
#  'ALDAKETA IMPORT\xadEXPORT, S.A.',
#  'ALFARMA, S.A.',
#  'ALIAM, S.A.',
#  'ALIANZA & COMPANIES INC.',
#  'ALINA INTERNATIONAL, S.A.',
#  'ALJORA INTERNATIONAL HOLDINGS INC.',
#  'ALL WORLD FOODS LTD.',
#  'ALLUSI, S.A.',
#  'ALMACENES EL TREBOL, S.A. DE C.V.',
#  'ALMACENES PRIETO, S.A.',
#  'ALTABANA, S.L.',
#  'ALTERNATIVE PRODUCTS & SERVICES (CANADA) INC.',
#  'ALZARA GRUPO DE COMUNICACIÓN, S.L.',
#  'AM GROUP, S.R.L.',
#  'AMADEUS IT GROUP, S.A.',
#  'AMCO APPLICATION MODERNE DE LA CHIMIE ORGANIQUE ETABLISSEMENT',
#  'AMCO APPLICATION MODERNE DE LA CHIMIE ORGANIQUE SOCIETE ANONYME',
#  'AMERICAN AIRLINES INC.',
#  'AMERICAN CANADIAN UNDERWATER CERTIFICATION INTERNACIONAL, S.L., A.C.U.C. INTERNACIONAL, S.L.',
#  'AMERICAN INTERNATIONAL TRADING PARTNERS, S.L.',
#  'AMORIM NEGOCIOS INTERNACIONAIS, S.A.',
#  'AMPELOS LATINAMERICA, S.A.',
#  'ANACO, B.V.',
#  'ANIS SERVICES, S.A.',
#  'ANJUBE, S.L.',
#  'ANSA McAL LIMITED',
#  'ANTILLANA DE EXPORT OFFICE ESPAÑA, S.L.',
#  'ANTILLES FRAIS, S.A.S.',
#  'ANÓNIMA ESPAÑOLA DE COMERCIO Y ECONOMÍA, S.A. (APOLO)',
#  'APLICACIONES TECNOLÓGICAS, S.A.',
#  'ARBELEC, S.L.',
#  'ARCA ́99, S.R.L.',
#  'ARGA CARIBE, S.L',
#  'ARIELA ́S INTERNATIONAL, S.A.',
#  'ARIZAGA, BASTARRICA Y CIA, S.A.',
#  'ART MUSIC, S.R.L.',
#  'ASIA FERRETERIA INDUSTRIAL, S.L.',
#  'ASIA-AMÉRICA INTERNACIONAL, S.A. / ECOTUR, S.A.',
#  'ASNAVAR, S.L.',
#  'ASTRA ZENEKA UK LIMITED',
#  'ASTRAZENECA UK LIMITED',
#  'ASTURIANA DE GRANALLADOS Y PINTURAS, S.A. (AGRAPISA)',
#  'ATAKA & CO., LTD.',
#  'ATHEL APLICACIONES Y TECNOLOGÍA, S.A.',
#  'AUSERVIS, S.L.',
#  'AVIATEXIM',
#  'AVIC INTERNATIONAL HOLDING CORPORATION',
#  'AZULEX SRO',
#  'B. BRAUN MEDICAL INTERNATIONAL, S.L.',
#  'B.B. NAFT TRADING, S.A.',
#  'B.D.C. INTERNATIONAL, S.A.',
#  'BACOU INTERSAFE INTERNATIONAL, B.V.',
#  'BAIONI CRUSHING PLANTS, S.P.A.',
#  'BARCELÓ EXPANSIÓN GLOBAL, S.L.',
#  'BASF DOMINICANA, S.A.',
#  'BAVARIA, N.V.',
#  'BAYER HANDELSGESELLSCHAFT M.B.H.',
#  'BE LIVE HOTELS, S.L.',
#  'BEIJING ENTERPRISES GROUP REAL-ESTATE CO., LTD.',
#  'BEIJING GREAT DRAGON INFORMATION TECHNOLOGY INTERNATIONAL CO., LTD.',
#  'BEIJING KEYUN LOGISTICS LTD. ',
#  'BEIJING NORTH STAR S&T DEVELOPMENT CO., LTD.',
#  'BEIJING ROSA INTERNATIONAL TRADING CO., LTD.',
#  'BEKAR IMPORTACIONES EXPORTACIONES, S.R.L.',
#  'BEL RAY ESPAÑA, S.A.',
#  'BELA-PHARM GMBH & CO. KG.',
#  'BELLO ALIMENTOS LTDA.',
#  'BETA MUSIC SAS, S.A.',
#  'BETICO COMPRESSORS, S.A.U.',
#  'BEYA TIME (NINGBO) INTERNATIONAL TRADE CO., LTD.',
#  'BGP INC., CHINA NATIONAL PETROLEUM CORPORATION',
#  'BILADU, S.A.',
#  'BILLABONA EXIMPORT, S.L.',
#  'BIOAMAZONAS-INDÚSTRIA E COMÉRCIO DE MEDICAMENTOS FITOTERÁPICOS LTDA.',
#  'BLACK JACK INTERNATIONAL, S.A.',
#  'BLANC-LABO, S.A.',
#  'BLUE PANORAMA AIRLINES, S.P.A.',
#  'BOJ OLAÑETA, S.L.',
#  'BOMBAS GRUNDFOS ESPAÑA, S.A.',
#  'BOMBAS IDEAL, S.A.',
#  'BORDOY Y ASOCIADOS CIA. LTDA.',
#  'BOUYGUES BATIMENT INTERNATIONAL, S.A.',
#  'BRANDSMA VORKHEFTRUCKS, B.V.',
#  'BRAVO PRODUCTS & EXPORTS INC.',
#  'BRIGEL, S.R.L.',
#  'BRYTESIDE TECH. INC.',
#  'BUREAU VERITAS',
#  'BYCOSIN AB',
#  'BYCOSIN AB, S.A.',
#  'C.D. SYSTEMS DE COLOMBIA, S.A.',
#  'C.P.M. DI CLAUDIO PIERMATTEI E.C., S.A.S.',
#  'C.R. TECHNOLOGY SYSTEMS, S.P.A.',
#  'C.R.TECHONOLOGY SYSTEM, S.R.L.',
#  'CABRERA Y PÉREZ, S.L.',
#  'CALIPSO ENTERPRISES LTD.',
#  'CALVO SEALING, S.L.',
#  'CAMAX CHILE, S.A.',
#  'CAMPAIOLI, S.R.L.',
#  'CANARAGUA, S.A.',
#  'CANARIAS DE PLÁSTICO, S.A.',
#  'CANCUB SANTANDER, S.L.',
#  'CAP-UNION, A.S.',
#  'CARECHEM DOMINICANA, S.R.L.',
#  'CARFIMAG 3000, S.R.L.',
#  'CARGO DEX, S.L.',
#  'CARGO LINES, S.A.',
#  'CARGO LINES, S.A.S.',
#  'CARGO SERVICES, S.A.',
#  'CARIBALT ALLIANCE OÜ',
#  'CARIBBEAN A.T.M. SERVICE LTD.',
#  'CARIBBEAN PRODUCERS AND SUPPLIERS, S.A.',
#  'CARIBBEAN SERVICES COMPANY INC.',
#  'CARIBE-MAR COMMERCIAL GROUP, S.A.',
#  'CARIBEMEX EXPORT-IMPORT, S.R.L.',
#  'CARNIVAL CORPORATION',
#  'CAROIL CHARTERING, S.A.',
#  'CAROIL TRANSPORT MARINE LIMITED',
#  'CASA BLANCA, S.A.',
#  'CASCO ANTIGUO COMERCIAL, S.L.',
#  'CASES & CASES',
#  'CASES & CASES, S.A.',
#  'CASES & CASES, S.A.U.',
#  'CASTEL ET FROMAGET, S.A.S.',
#  'CASTOR PLUS, S.L.',
#  'CB CARIBBEAN SUPERVISION LTD.',
#  'CBC BUSINESS CENTER INC. (A.G./S.A.)',
#  'CBC GLOBAL BUSINESS LTD.',
#  'CECAUTO LOGÍSTICA, S.L.',
#  'CEIBA PROPERTY CORPORATION LIMITED',
#  'CENTRE DU CAMION GAMACHE INC.',
#  'CENTRUM, S.A. DE C.V.',
#  'CES CO., LTD.',
#  'CEXVAL, S.A.',
#  'CGC INVESTMENT LLC',
#  'CHANDRU INTERNATIONAL EXPORTS, S.L.',
#  'CHEMATEK, S.P.A.',
#  'CHILI TECHNOLOGIES, S.L.',
#  'CHINA AUTO CAIEC LTD.',
#  'CHINA MEHECO CORPORATION',
#  'CHINA NATIONAL AUTOMOTIVE INDUSTRY IMPORT & EXPORT CORPORATION (CAIEC)',
#  'CHINA NATIONAL AUTOMOTIVE INDUSTRY INTERNATIONAL CORPORATION ',
#  'CHINA NATIONAL COMPLETE PLANT IMPORT AND EXPORT CORPORATION (GROUP)',
#  'CHINA NATIONAL COMPLETE PLANT IMPORT AND EXPORT CORPORATION LIMITED',
#  'CHINA NATIONAL ELECTRIC ENGINEERING CO., LTD. (CNEEC)',
#  'CHINA NATIONAL HUACHEN ENERGY GROUP CO., LTD.',
#  'CHINA NATIONAL MACHINERY IMPORT AND EXPORT CORPORATION',
#  'CHINA NORTH VEHICLE CORPORATION LTD. (NORINCO MOTORS)',
#  'CHINA NORTHERN LOCOMOTIVE & ROLLING STOCK INDUSTRY GROUP',
#  'CHINA PETROLEUM TECHNOLOGY AND DEVELOPMENT CORPORATION (CPTDC)',
#  'CHINA YANY INTERNATIONAL TRADE CORPORATION LTD.',
#  'CICLAUTO AUTOMOCION, S.L.',
#  'CLUB DE INVERSIONES DEL GUADAIRA, S.A.',
#  'CMA-CGM AGENCIES WORLDWIDE',
#  'COIVEX, S.A.',
#  'COMARGO COMPOSITES, S.L.',
#  'COMEFIN, A.G.',
#  'COMEFIN, A.G., S.A.S.',
#  'COMERCIAL CAIMAN INTERNACIONAL, S.A.',
#  "COMERCIAL D'ARGONI ESPAÑA, S.L.",
#  "COMERCIAL D'ARGONI, S.A.",
#  'COMERCIAL DE LA INDUSTRIA IMPORTACIÓN EXPORTACIÓN, S.A. (CINIESA)',
#  'COMERCIAL DE TRANSMISIONES, S.A.',
#  'COMERCIAL DE TRIPAS Y ADITIVOS, S.L.',
#  'COMERCIAL DOS BOCAS, S.A. DE C.V.',
#  'COMERCIAL E INDUSTRIAL TRES LIRIOS, S.A.',
#  'COMERCIAL IMPORMOVIL, S.A.',
#  'COMERCIAL MASOLIVER, S.A.',
#  'COMERCIAL PROMERKA, S.A.',
#  'COMERCIAL SURIMPEX LTDA.',
#  'COMERCIAL TAKE OFF, S.A. / CAN-SHIP IMPORT-EXPORT INC.',
#  'COMERCIAL TAKE OFF, S.A. / EL NERVION, S.A. DE C.V.',
#  'COMERCIAL TAKE OFF, S.A. / EL NERVION, S.A. de C.V.',
#  'COMERCIAL TAKE OFF, S.A. / GECI ESPAÑOLA, S.A.',
#  'COMERCIAL TAKE OFF, S.A. / MULTIPRO, S.A. (2001) INC.',
#  'COMERCIAL TAKE OFF, S.A. / TLD EUROPE, S.A.S.',
#  'COMERCIAL TAKE OFF, S.A. / VNIIRA-OVD',
#  'COMERCIAL TOLEDO, S.A.',
#  'COMERCIAL WHITEHORN, S.A.',
#  'COMERCIAL YARA, S.A.',
#  'COMERCIALIZADORA CTS CHILE LTDA.',
#  'COMERCIALIZADORA QBA 1, C.A.',
#  'COMERCIALIZADORA S & E Y CIA., S.A.',
#  'COMERCIALIZE CARIBEAN INTERNATIONAL, S.A. DE C.V.',
#  'COMERIND, S.L.',
#  'COMEX, S.R.L.',
#  'COMIMPEX HANDELSGESELLSCHAFT MBH & CO. KG',
#  'COMINVESTMENT, A.G.',
#  'COMLAT, S.A.',
#  'COMPAGNIA MERCANTILE INTERNAZIONALE, S.R.L. (COMEI)',
#  'COMPANHIA DE OBRAS E INFRA-ESTRUCTURA (COI)',
#  'COMPAÑIA ELABORADORA DE CAUCHO COECA, S.A.',
#  'COMPAÑÍA COMERCIAL FERMIGUA, S.A.',
#  'COMPAÑÍA DE COMERCIO EXTERIOR ALLWE, S.A.',
#  'COMPAÑÍA DE ESTUDIOS, SERVICIOS Y TECNOLOGÍAS APLICADAS, S.L. (CESYTA)',
#  'COMPAÑÍA MERCANTIL DE LAS AMÉRICAS, S.A.',
#  'COMPAÑÍA MEXICANA DE AVIACIÓN, S.A DE C.V.',
#  'COMPAÑÍA PANAMEÑA DE AVIACIÓN, S.A. (COPA AIRLINES)',
#  'COMPAÑÍA RIO, S.A.',
#  'COMPAÑÍA TREBOR, S.A.',
#  'COMPRESORES REDIN, S.A.L.',
#  'CON-IMPEX HANDELSGESELLSCHAFT MBH',
#  'CON-IMPEX HANDELSGESELLSCHAFT MBH & CO. KG',
#  'CONCO INTERNACIONAL, S.A.',
#  'CONDAL TRADE BARCELONA, S.A.',
#  'CONICKEL INC.',
#  'CONSERVAS DE CAMBADOS, S.A.',
#  'CONSERVAS DE CAMBADOS, S.L.',
#  'CONSIGNACIONES TRÁNSITOS Y TRANSPORTES INTERNACIONALES, S.A. (COTRANSA)',
#  'CONSORCIO INDUSTRIAL SHESGA, S.L.',
#  'CONSORCIO INDUSTRIAL TREFON, S.A. DE C.V.',
#  'CONSORCIO VENEZOLANO DE INDUSTRIAS AERONÁUTICAS Y SERVICIOS AÉREOS, S.A.',
#  'CONYCAL, S.A.',
#  'CORAL CAPITAL CORP.',
#  'CORAL CARIBE, S.L.',
#  'CORDEX, S.R.L.',
#  'CORECASA MPYD, S.A.',
#  'CORECASA UNIFORMES, S.A.',
#  'CORONADO Y SAQUILMER Y COMPAÑÍA LIMITADA',
#  'CORPORACION AUTOMOTRIZ LATINOAMERICANA, S.A.',
#  'CORPORACIÓN DE COMERCIO DE ARTESANÍA DE JIANGXI LTD.',
#  'CORPORACIÓN DE COMERCIO DE ARTESANÍA DE JIANGXI, S.A.',
#  'CORPORACIÓN DE COMERCIO DE ARTESANÍA DE JIANGXI, S.L.',
#  'CORPORACIÓN DE EXPORTACIÓN DE LA REPÚBLICA DE TATARSTÁN, S.A.',
#  'CORPORACIÓN DE IMPORTACIÓN Y EXPORTACIÓN DE LOS PRODUCTOS EDUCATIVOS Y DEPORTIVOS EN GUANGDONG',
#  'CORPORACIÓN INTERNACIONAL Z. MAR CRIVING, C.A.',
#  'CORPORACIÓN INTERNACIONAL Z. MAR, CRIVING, C.A.',
#  'CORPORACIÓN LINK A.V.V.',
#  'CORPORACIÓN LOGÍSTICA DEL CARIBE, S.A.',
#  'CORPORACIÓN NACIONAL CHINA PARA LA IMPORTACIÓN Y EXPORTACIÓN DE MAQUINARIAS DE CONSTRUCCIÓN Y AGRÍCOLAS (CAMC)',
#  'CORPORACIÓN NACIONAL DE EQUIPOS ELÉCTRICOS DE CHINA (CNEEC)',
#  'CORPORACIÓN PANAMERICANA, S.A. / COMERCIAL CARIMEX, S.A. DE C.V.',
#  'CORPORACIÓN PANAMERICANA, S.A. / ETCO INTERNATIONAL COMMODITIES LTD.',
#  'CORSAN MARINE (1998) INC.',
#  'COSMOS COMMERCIAL GROUP, S.A.',
#  'COVERTRADE, S.L.',
#  'CREACIONES META, S.A.',
#  'CREO TRADE INC.',
#  'CRIBAS Y TAMICES INTERVENISPA, S.L.',
#  'CRRC GROUP CO., LTD.',
#  'CRS BRANDS INDUSTRIA E COMERCIO LTDA.',
#  'CRYMSA IMPORT EXPORT, S.A.',
#  'CUBAFREETAX B.V. (LATIN TULIP DUTY FREE B.V.)',
#  'CUBANGOMODA INTERNACIONAL, S.A.',
#  'CUBATUR, S.A. / GRUPO GIRA, S.A.',
#  'CUBATUR, S.A. / VIAJES EL CORTE INGLÉS, S.A.',
#  'CUBATUR, S.A. / VIAJES Y REPRESENTACIONES, S.L.',
#  'CUBINVEST LIMITED',
#  'CUEX, S.A.',
#  'CUGRANCA, S.A.',
#  'CURPSAP, S.L.',
#  'CUSEKO INTERNATIONAL CO., LTD.',
#  'CYPREOS-FRANCE EPONGES',
#  'D ́MARCO, S.A.',
#  'DAIQUIRÍ TOURS, S.A.',
#  'DALIAN GOLDEN TIME ENTERPRISE CO., LTD.',
#  'DALLANT, S.A.',
#  'DANYEL BIOTECH LTD.',
#  'DASHE GROUP 2018, S.L.',
#  'DAYS TOURS TURISZM VE ORGANIZASYON LIMITED SIRKETI, S.L. / VIAJES CUBANACÁN, S.A.',
#  'DC-SYSTEM INSULATION A/S',
#  'DE GRAAF HOLDING EN TRADE B.V.',
#  'DEHAVEN TRADE GMBH',
#  'DEHISPA, S.L.',
#  'DELATRADE HANDELSGESELLSCHAFT MBH',
#  'DELAVAL INTERNATIONAL, A.B.',
#  'DELTA AIR LINES INC.',
#  'DESECHOS TEXTILES DEL CARIBE, S.R.L. (DETEXCA)',
#  'DESTILERÍAS MG, S.L.',
#  'DEUTSCHE LUFTHANSA AKTIENGESELLSHAFT',
#  'DEVEXPORT',
#  'DEVOX, S.A. DE C.V.',
#  'DI 7, S.L.',
#  'DISTAL, S.R.L.',
#  'DISTRIBUIDORA AMASA, S.A. DE C.V.',
#  'DISTRIBUTIONS FÉLISOL INC.',
#  'DMAX DISTRIBUTORS LTD.',
#  'DNV GL, S.E.',
#  'DOINSA HISPANIA, S.L.',
#  'DOMINGO ALONSO INTERNACIONAL, S.L.',
#  'DRESEN QUIMICA, S.A. DE C.V.',
#  'DRESEN QUIMICA, S.A.P.I. DE C.V.',
#  'DRIZORO, S.A.',
#  'DURABOND PRODUCTS LIMITED',
#  'ECHO-EXPORT, S.R.L.',
#  'ECOGEO SERVIZI ALLE IMPRESE, S.R.L.',
#  'ECV CARIBE PANAMÁ, S.A.',
#  'EDETRA, S.A.',
#  'EGONDI ARTES GRAFICAS, S.A.',
#  'EGONDI ARTES GRÁFICAS, S.A.',
#  'EL CUARTO DEL REGUERÓN, S.L.',
#  'EL ESTABLO, S.A.',
#  'EL ESTABLO, S.R.L.',
#  'ELAZ, S.L.',
#  'ELDA FASHION, S.L.',
#  'ELECTRA VITORIA, S. COOP.',
#  'ELECTROAIR TRADE OÜ',
#  'ELECTROMEDICA INTERNACIONAL, S.A. ',
#  'ELECTRÓNICA ARA, S.L.',
#  'ELETROFLEX COMERCIAL EXPORTADORA LTDA.',
#  'ELETTRICA VICENTINA, S.P.A.',
#  'ELETTRICA VICENTINA, S.R.L.',
#  'ELITE TRADING INTERNATIONAL, S.A.',
#  'ELOF HANSSON INTERNATIONAL, A.B.',
#  'EMA-CER, S.R.L.',
#  'EMILDUE, S.R.L.',
#  'EMM, MERCHANDISE EXPORT\xadIMPORT LTD.',
#  'EMPRESA COMERCIALIZADORA VIGLACERA',
#  'EMPRESA DR. ING. GIOVANNI TOGNOZZI, S.P.A.',
#  'EMPROMOULDS, S.A.',
#  'EMYSA CORPORATION',
#  'ENERTRAN, S.A.',
#  'EPROMEXT, S.L.',
#  'EQUIPAMIENTO INSTITUCIONAL, S.A. (EKINSA)',
#  'ERGOS CONTINENTAL, S.A. / VIAJES CUBANACÁN, S.A.',
#  'ERICSSON, A.B.',
#  'ESCANDON PLUS, S.A.',
#  'ESCANDON PLUS, S.L.',
#  'ESENCIA FINANCE AND CONSULTING, S.L.',
#  'ESFERA 2000, S.A.',
#  'ETABLISSEMENTS J. SOUFFLET, S.A.',
#  'ETCO INTERNATIONAL COMMODITIES LTD.',
#  'EUMEDA GMBH',
#  'EUPINCA, S.A.',
#  'EURICOM, S.P.A.',
#  'EUROMAT EXPORT, S.L.',
#  'EUROPA TECHNIC GMBH',
#  'EUROQUIMICA PAINTS, S.A.',
#  'EUROSIBA, S.A.',
#  'EUROTRADE WORLD COMMERCE, S.L.',
#  'EUSKAL HERRIA (EUSKAL ENPRESEN TALDEA) LIMITED',
#  'EUTECTIC CANADA LTD.',
#  'EVELOP AIRLINES, S.L. (IBEROJET AIRLINES)',
#  'EXCLUSIVES TOT COLOR, S.A.',
#  'EXINVARE, S.L.',
#  'EXPOMAYAB, S.A. DE C.V.',
#  'EXPORT DUPRASA, S.L.',
#  'Empresa Importadora para el Comercio Interior, COMIMPORT, en la Empresa Comercializadora de Artículos en General, CONSUMIMPORT, ambas integradas al Grupo Empresarial del Comercio Exterior, GECOMEX',
#  'Eupinca, S.A.',
#  'F.M. COEMPAR COMERCIAL LTDA.',
#  'FABRICADOS ELECTROMECÁNICOS ESTÉVEZ FABREZ, S.L.',
#  'FACEX, S.L.',
#  'FACIMPEX DOMINICANA, S.R.L.',
#  'FAGOR INDUSTRIAL S. COOP.',
#  'FAI-BERTI, S.L.',
#  'FARIVAL, S.A.',
#  'FARMAVENDA, S.P.A.',
#  'FARMER, S.R.L.',
#  'FECOM',
#  'FECOM, S.A.',
#  'FEMAG FERRI MAGNETICI, S.R.L.',
#  'FERPA GRAPHIC, S.L.',
#  'FERRETERIA UNCETA, S.A.',
#  'FERRETERÍA COMERCIAL, S.A.',
#  'FERRETERÍA UNCETA, S.A.',
#  'FERRING PHARMACEUTICAL BV.',
#  'FERRING, S.A. DE C.V.',
#  'FERRIS MANAGEMENT LIMITED',
#  'FERROMET AKCIOVÁ SPOLECNOST',
#  'FERROSTAAL MEXICO, S.A. DE C.V.',
#  'FERSUME, S.L.U.',
#  'FICUBA, S.L.',
#  'FINAUTO INTERNATIONAL LIMITED',
#  'FINCALA, A.V.V.',
#  'FINSALE COMPANY LIMITED',
#  'FIXATION R. & M. SERVICES LTD.',
#  'FIXED & MOBILE PTE. LIMITADA',
#  'FLORIC INTERNATIONAL LIMITED',
#  'FLY ALWAYS N.V.',
#  'FN INTERNACIONAL, S.L.',
#  'FOMESA AGROINDUSTRIAL, S.L.',
#  'FONDO JUVENIL UCRANIANO DE CHERNOBIL',
#  'FONDON REDES Y FLUIDOS, S.L.',
#  'FOREGO INTERNATIONAL LIMITED',
#  'FOREING TRADE COMPANY ALLWE, S.A.',
#  'FORMULA EXPORT & IMPORT, S.A.',
#  'FRA. VA., S.R.L',
#  'FRAGUAR, S.L.',
#  'FRAMA, S.P.A.',
#  'FRISHER, S.R.L.',
#  'FROXA, S.A.',
#  'FTC, S.R.L.',
#  'FUETA INTERNATIONAL CO., LTD.',
#  'FUGRAN COMERCIAL E INDUSTRIAL, S.A.',
#  'FUJIAN HUAYUAN WELL IMPORT & EXPORT TRADE CO., LTD.',
#  'FUJIAN PROVINCE OVERSEAS CHINESE INDUSTRIAL GROUP CO. (FOCIG)',
#  'FUJIAN PROVINCE OVERSEAS CHINESE INDUSTRIAL GROUP CO., LTD.',
#  'FURBIA INTERNATIONAL, S.A.',
#  'FUTURA SYSTEMS, S.L.',
#  'FUYANSA INTERNATIONAL CO., LTD.',
#  'GAFER IMPORTACION-EXPORTACION, S.L.',
#  'GALAX INC.',
#  'GAMMA EXPORT, S.R.L.',
#  'GARANT CO., LTD.',
#  'GARONDA, S.L.',
#  'GBM COMMUNICATIONS, S.A.',
#  'GECOM GENOVESE COMMERCIALE, S.R.L.',
#  'GEELY INTERNATIONAL CORPORATION',
#  'GEN POWER HOLDING, S.A.',
#  'GENERAL ELECTRIC INTERNATIONAL INC.',
#  'GERMAN-TEC (PANAMÁ), S.A.',
#  'GERMANISCHER LLOYD, S.E.',
#  'GERMANISHER LLOYD, A.G.',
#  'GERMANTEC (PANAMA), S.A.',
#  'GESMESOL, S.A.',
#  'GESTINOX, S.L.',
#  'GESTIÓN EMPRESARIAL MALLORQUINA, S.L.',
#  'GIBRALTAR TRADING, C.A.',
#  'GIEINTER, A.G.',
#  'GILL & DUFFUS, S.A.',
#  'GILMAR PROJECT FINANCE ESTABLISHMENT',
#  'GIRBAU, S.A.',
#  'GISMO GROUP, S.A.',
#  'GLIOLA, S.A.',
#  'GLOBAL SUGAR TRADING-COMERCIO DE AÇUCAR LDA.',
#  'GOLD BLACK INVESTMENTS, S.A.',
#  'GONZALO INTERNACIONAL DE OPERACIONES, S.L.',
#  'GOSTARESH KESHT TEHERAN (TAD CO.)',
#  'GRACE GROUP CO., LTD.',
#  'GREATWALL DRILLING COMPANY LTD.',
#  'GREENBELT HOLDINGS LTD.',
#  'GREYMO, S.A.',
#  'GROUPE BERNARD HAYOT, S.A.S.',
#  'GRUPO ARMARIOS PERSIANA, S.A. (SOCIEDAD UNIPERSONAL)',
#  'GRUPO AUTOMOCIÓN MUTAUTO AMÉRICA, S.L.',
#  'GRUPO BM INC.',
#  'GRUPO CTT, S.A. DE C.V.',
#  'GRUPO DE AUTOMOCION MUTAUTO AMERICA S.L. (GAMA S.L.)',
#  'GRUPO DOMOS INTERNACIONAL, S.A. DE C.A.',
#  'GRUPO DOMOS INTERNACIONAL, S.A. DE C.V.',
#  'GRUPO EXPORTADOR E IMPORTADOR DE PRODUCTOS PLÁSTICOS, S.A. DE C.V.',
#  'GRUPO GESTIÓN CARIBE, S.A.',
#  'GRUPO INDUSTRIAL MARÍTIMO, S.A.',
#  'GRUPO INTERNACIONAL CARBACAN, S.A. (GICSA)',
#  'GRUPO KAPAN INTERNACIONAL, S.A.',
#  'GRUPO PLASVISA EXPORT, S.L.',
#  'GRUPO SANTA MÓNICA INTERNACIONAL, S.A.',
#  'GRUPO TCI, S.A.',
#  'GRUPO TEXTIL CASABELLA, S.A. DE C.V.',
#  'GRUPO UGAO, S.A.',
#  'GUARCONSA, S.A.',
#  'GULF LAKE ENTERPRISES LTD.',
#  'HA INGENIEROS, S.A. DE C.V.',
#  'HAIER GLOBAL COMERCIO CORPORACIÓN LIMITADA',
#  'HAMBURG SUDAMERIKANISCHE DAMPFSCHIFFAHRTS-GESELLSCHAFT KG',
#  'HAMBURG SUDAMERIKANISCHE DAMPFSCHIFFFAHRTS-GESELLSCHAFT A/S & Co. KG',
#  'HANGZHOU DUOJIA TECHNOLOGY CO., LTD.',
#  'HARARI MS S.R.L.',
#  'HAUX-LIFE-SUPPORT GMBH',
#  'HAVANA ENERGY LIMITED',
#  'HAVANA HOLDINGS LIMITED',
#  'HELLMAN WORLDWIDE LOGISTICS (CUBA) GMBH',
#  'HELVEX, S.A. DE C.V.',
#  'HEMO DIAGNOSTICA S.R.L.',
#  'HENAN MUNDIAL IMPORT & EXPORT TRADE CO., LTD.',
#  'HERMANOS TOIMIL GARCIA, S.L.',
#  'HI TEC CARIBE, S.A.',
#  'HIJOS DE C.V. OTERO, S.L.',
#  'HISPANO CUBANA DE INTERIORES, S.L.',
#  'HITACHI HIGH-TECHNOLOGIES CORPORATION',
#  'HODGSON SUGAR LTD.',
#  'HOLSON CORP.',
#  'HOMEPORT CANADA INC.',
#  'HOTELSA ALIMENTACIÓN, S.L.',
#  'HOTZ BERRI, S.L.',
#  'HOTZ BERRI, S.L.U.',
#  'HPLUS COMERCIO FARMACÉUTICO INTERNACIONAL, S.A.',
#  'HUAWEI TECHNOLOGIES PANAMÁ, S.A.',
#  'HUTCHINSON, S.N.C.',
#  'HUZHOU HUAFANG IMP & EXP CO., LTD.',
#  'HYDRO DIFUSIÓN, S.L.',
#  'HYUNDAI CORPORATION',
#  'I.F. ARTE, COMUNICACIÓN E IMAGEN LDA.',
#  'IBADESA CANARIAS, S.L. (IBADECAN)',
#  'IBADESA TRADING, S.A.',
#  'IBALUCE, S.L.',
#  'IBC RESIGUM INTERNATIONAL, S.R.L.',
#  'IBEC SYSTEMS, S.L',
#  'IBERCUB SUMINISTROS INDUSTRIALES Y HOTELEROS, S.A.',
#  'IBERIA, LÍNEAS AÉREAS DE ESPAÑA, S.A.',
#  'IBERIA, LÍNEAS AÉREAS DE ESPAÑA, S.A. OPERADORA',
#  'IBERO TRUST DE MERCADOS, S.A.',
#  'ICDQ INSTITUTO DE CERTIFICACIÓN, S.L.',
#  'IDON INTERNATIONAL TRADING CO., LTD.',
#  'IGLESIAS INTERNATIONAL (1996) CORPORATION',
#  'ILEATEX, S.A.',
#  'ILHA BELA GESTAO E TURISMO UNIPESSOAL LDA.',
#  'IMPERIAL ZONA LIBRE, S.A.',
#  'IMPEX SUMINISTRES, S.L.',
#  'IMPORTADORA Y EXPORTADORA SEVILLA, S.A.',
#  'IMPORTADORA, EXPORTADORA Y COMERCIALIZADORA MTG LTDA.',
#  'IMPRESUB VENEZUELA, S.A.',
#  'IMPULSORA MARMUR, S.A. DE C.V.',
#  'INALCA, S.P.A.',
#  'INDACO LIMITED',
#  'INDUSTRIA Y COMPLEMENTOS PARA EL LABORATORIO, S.L.',
#  'INDUSTRIAL MOLINERA E.X., S.A. DE C.V.',
#  'INDUSTRIAL SEDO, S.L.',
#  'INDUSTRIAS CÁRNICAS BLANCAFORT, S.A.',
#  'INDUSTRIAS LEHNER, S.A.',
#  'INDUSTRIAS METALÚRGICAS SOROA, S.L.',
#  'INDUSTRIAS TITAN, S.A.U.',
#  'INDUSTRIES AUSTRALIA PTY LTD.',
#  'INEKON POWER, S.A.',
#  'INFIFON, A.P.S.',
#  'INFRA, S.A. DE C.V.',
#  'INGENIERÍA GASTRONÓMICA, S.A.',
#  'INGENIERÍA Y COMERCIO, S.A.',
#  'INGENIERÍA Y SUMINISTROS ASTURIAS, S.A.',
#  'INKUG, S.L.',
#  'INSECTICIDAS INTERNACIONALES, C.A.',
#  'INSPUR GROUP CO., LTD.',
#  'INSTRUMENTATION & AUTOMATISATION EXCELTEC INC.',
#  'INTALS, S.P.A.',
#  'INTELCAN TECHNOSYSTEMS INC.',
#  'INTERCARIBBEAN AIRWAYS LTD.',
#  'INTEREX CANADA INC.',
#  'INTERFOOD AMERICAS, S.A.',
#  'INTERGLOBE INC.',
#  'INTERNACIONAL DEL COMERCIO NADINE, S.L.',
#  'INTERNATIONAL ABC IMPORT-EXPORT, S.A.',
#  'INTERNATIONAL CARIBBEAN SUPPLIER, S.A.',
#  'INTERNATIONAL CLOTHING COMPANY INC.',
#  'INTERNATIONAL NESS CORPORATION, S.A.',
#  'INTERNATIONAL NETWORK GROUP, S.A.',
#  'INTERNATIONAL SCIENTIFIC ENTERPRISE & DISTRIBUTION N.V. (ISED INC.)',
#  'INTORD, S.A.',
#  'INVERSIONES GRAJAL, S.A.',
#  'INVERSIONES HOLLEN, S.A.',
#  'INVERSIONES PUCARA, S.A.',
#  'INVERSIONES ROEDER, S.A.',
#  'IRRIGATION COMPONENTS EUROPE, S.L. ',
#  'IRRITEC IBERIA, S.A.',
#  'ISAGRO, S.P.A.',
#  'ISOLTEC CORP.',
#  'ISOTRON, S.A.U',
#  'ITAL RECAMBIOS, S.A.',
#  'ITALSAV, S.R.L.',
#  'ITALTRADER, S.R.L.',
#  'ITAME CONSULT S.N.C. DE RAFFAELE TETTI & C',
#  'IVEKTA, S.R.L.',
#  'IVORYCHEM PTE LTD.',
#  'Intals, S.P.A.',
#  'JACQUES SCOTT & COMPANY LIMITED',
#  'JAR ELECTRÓNICA APLICADA, S.A. DE C.V.',
#  'JEALSER, S.A.',
#  'JEAR TÉCNICA, S.A.',
#  'JETBLUE AIRWAYS CORPORATION',
#  'JIANGSU GANGHONG ELECTRIC WIRE & POWER CABLE CO., LTD.',
#  'JIANGXI JIANGLING MOTORS IMPORT & EXPORT CO., LTD.',
#  'JIANGXI MACHINERY & EQUIPMENT IMPORT & EXPORT CORPORATION',
#  'JINHUA HUAMAO COMMODITY TRADE CO., LTD.',
#  'JINHUA HUAMAO IMPORT & EXPORT CO., LTD.',
#  'JINJIANG JIANDA GARMENTS AND WEARING, CO., LTD.',
#  'JOAN SARDÁ, S.A.',
#  'JOANI COMMERCIAL CORP.',
#  'JOHAO INTERNATIONAL, S.A.',
#  'JOHN BULL LIMITED',
#  'JSC ZARUBEZHNEFT',
#  'JUANITA MATEO, S.L.',
#  'JULSA INDUSTRIAL, S.A.',
#  'JURCAL, S.A.',
#  'KARL STORZ ENDOSCOPIA, S.A. DE C.V.',
#  'KENIA, S.A.',
#  'KLINGER SAIDI SPAIN, S.A.U.',
#  'KNAUF GMBH',
#  'KOMNOT CORPORATION',
#  'KONINKLIJKE LUCHTVAART MAATSCHAPPIJ, N.V.',
#  'KONIXBERT HI-TECH, S.A.',
#  'KRENER INTERNACIONAL, S.L.',
#  'KSB ITUR SPAIN, S.A.',
#  'KUEHNE NAGEL LOGISTIC SERVICES, S.A.',
#  'KYOEI INTERNATIONAL CO., LTD.',
#  'L.B.S. DISTRIBUTION LTD.',
#  'L.R. MORONI CELLULOSE CONVERTING MACHINERY, S.R.L.',
#  'LA CORONACIÓN, S.A. / ECOTUR, S.A.',
#  'LA FUENTE SEGOVIA, S.L.',
#  'LABORATORIOS BAGÓ, S.A.',
#  'LABRECO TRADE, S.A.',
#  'LAFUENTE SEGOVIA, S.L.',
#  'LAN PERÚ, S.A.',
#  'LAS PAILAS DE CEMENTO, S.A.',
#  'LATIN MOTORES, S.R.L.',
#  'LATIN TULIP DUTY FREE B.V.',
#  'LBS DISTRIBUTION LTD.',
#  'LECIÑENA, S.A.',
#  'LIAONING MEC GROUP CO., LTD.',
#  'LIDER ALIMENT, S.A.',
#  'LIDO INTERNACIONAL, S.A.',
#  'LINCE MOBILIARIO, S.L.',
#  'LINDMED TRADE, S.L.',
#  'LINPORT, S.A.',
#  'LINYI FAR EAST IMPORT & CO., LTD.',
#  'LIPPOEL TOBACCO CORPORATION INTERNATIONAL, S.A.',
#  "LLOYD'S REGISTER EMEA",
#  'LOGIGRAF, S.L.',
#  'LOGISPRINT',
#  'LOHRMANN INTERNATIONAL GMBH',
#  'LOMISA DISTRIBUCIONES Y PROYECTOS, S.L.',
#  'LOTUM, S.A.',
#  'LOUIS DREYFUS COMMODITIES FRANCE, S.A.S.',
#  'LOUIS DREYFUS COMMODITIES SUISSE, S.A.',
#  'LOUIS DREYFUS COMPANY SUISSE, S.A.',
#  'LOURDES VENTURES, S.A.',
#  'LOUVRE HOTELS GROUP',
#  'LPL INTERNATIONAL, B.V.',
#  'LUBRICANTES ARGENTINOS DE ALTA PERFORMANCE, S.A. (LAAPSA)',
#  'LUCIA ALTIERI, S.R.L',
#  'LUXEMBOURG INDUSTRIES LTD.',
#  'LÍNEAS AÉREAS COSTARRICENSES, S.A.',
#  'LÍNEAS AÉREAS DE ANGOLA (TAAG)',
#  'M&D TRADING, C.A.',
#  'M. CAMACHO INTERNACIONAL, S.L.',
#  'MADRID BUSINESS SERVICES, S.L.',
#  'MADRID HOSTELERÍA DE SUMINISTROS, S.L.',
#  'MAGIC TRADING, S.A.',
#  'MAJESTIC DISPENSING SYSTEMS',
#  'MAKRO SOLUCIONES DE TECNOLOGÍA, S.A.',
#  'MALTA TEXO DE MEXICO, S.A DE C.V',
#  'MAN DIESEL & TURBO ESPAÑA, S.A.',
#  'MAN ENERGY SOLUTIONS ESPAÑA, S.A.',
#  'MAN FERROSTAAL MEXICO, S.A. de C.V.',
#  'MANGUERAS ESPECIALIZADAS, S.A. DE C.V.',
#  'MANIPULACIONES PORTUARIAS GRUPAJES Y TRÁNSITOS, S.A.',
#  'MANUCHAR, N.V.',
#  'MANUEL ESPEJO INTERIORISMO & DECORACIÓN, S.L.',
#  'MANUEL REVERT Y CIA., S.A.',
#  'MARADA TRADING, S.L.',
#  'MARCAFIX, S.A.',
#  'MARCARIBE INTERNACIONAL TURISMO LTD.',
#  'MARCARIBE INTERNATIONAL TURISMO, S.L.',
#  'MARCHI, S.R.L.',
#  'MAREGINA INVESTMENT INC.',
#  'MARINTER, S.A.',
#  'MARRIOT INTERNATIONAL INC.',
#  'MARTINAIR HOLLAND, N.V.',
#  'MARUBENI CORPORATION',
#  'MARÍTIMA DEL GOLFO, S.L.',
#  'MASTER & MASTER TRADING CORP., S.A.',
#  'MATCO, S.R.L.',
#  'MAXIVIDRO TRANSFORMADORES E DISTRIBUIDORES DE VIDRIO, S.A.',
#  'MAYEKAWA DE MÉXICO, S.A. DE C.V.,',
#  'MAYOR CATALANA, S.L.',
#  'MEDAVAN, S.A. DE C.V.',
#  'MEDICARIBE, S.A.',
#  'MEDINABI RODAMIENTOS, S.L.',
#  'MEGO, S.R.L.',
#  'MELGASAL INVEST, S.L. ',
#  'MERCANTIL ESPAÑOLA DE REFRIGERACION, S.L. (FRIGER)',
#  'MERCK, S.A.',
#  'MERINTER LTDA.',
#  'MERINTER, S.P.A.',
#  'METALLICA CARIBBEAN, S.A.',
#  'MG CUBA DELEGACIÓN, S.L.',
#  'MICROCLIMA, S.A.',
#  'MIESA EXPORTACION, S.L.',
#  'MIESA INGENIERÍA, S.A.',
#  'MIESA, S.A.',
#  'MIGUEL CARRERA Y CIA., S.A.',
#  'MIGUEL CARRERA Y COMPAÑÍA, S.A.',
#  'MIGUEL TORRES, S.A.',
#  'MISTRAL CARIBE HOLDING, S.A.',
#  'MITEL NETWORKS CORPORATION',
#  'MITSUBISHI CORPORATION',
#  'MITSUI & CO., LTD.',
#  'MLL CARIBE, S. DE R.L.',
#  'MLW INTERMED HANDELS-UND CONSULTINGGESELLSCHAFT FÜR ERZAUGNISSE UND AUSRÜSTUNGEN DES GESUNDHEITS- UND BILDUNGSWESSENS mbH',
#  'MLW INTERMED HANDELS-UND CONSULTINGGESELLSCHAFT MBH',
#  'MONDEVI S.L., IMPORT EXPORT INC DIVISIÓN AMÉRICA',
#  'MONTERO FYE, S.A.',
#  'MORIM NEGOCIOS INTERNACONAIS, S.A.',
#  'MOTOINSA, S.A.',
#  'MSC FÁBRICAS AGRÍCOLAS, S.L.',
#  'MTG EXPORT-IMPORT',
#  'MUTSUMI TRADING CO., LTD.',
#  'MÚLTIPLE TRADING INC.',
#  'N.S.V., S.L.',
#  'NANTONG XINLIJI INTERNATIONAL CO., LTD.',
#  'NAUTILUS SHIPPING OVERSEAS CORP.',
#  'NAVEMAR, S.A.',
#  'NECTAR GROUP LIMITED',
#  'NELSON SERVIZI, S.R.L.',
#  'NENEKA, C.A.',
#  'NEOS, S.P.A.',
#  'NETICOM KERNEL INC.',
#  'NEXUS LOGISTICS, S.A.',
#  'NHAT TRANG TRADE & TOURISM CO., LTD.',
#  'NINGBO FREE TRADE ZONE WAMA INTERNATIONAL TRADE CO., LTD.',
#  'NINGBO HUAMAO INTERNATIONAL TRADING CO., LTD.',
#  "NINGBO ZHAOKE INT'L IMP. & EXP. CORP.",
#  'NIRINT SHIPPING, B.V.',
#  'NORALTA INTERNATIONAL',
#  'NORDSTRAND MARITIME AND TRADING COMPANY LIMITED',
#  'NORTH WORLD INDUSTRY INC.',
#  'NORTHSOUTH MARITIME COMPANY LIMITED',
#  'NOVARTIS, A.G.',
#  'NOVAXA ORTODONZIA, S.R.L.',
#  'NR ELECTRIC CO., LTD.',
#  'NSV, S.L.',
#  'NUEVA COMPAÑÍA DE INDIAS, S.A.',
#  'NUOVA MODA ITALIA, S.R.L.',
#  'Nueva Compañía de Indias, S.A.',
#  'OAO “CONSORCIO ENERGOTECNOLOGÍAS”',
#  'OCCIDENTAL HOTELES MANAGEMENT, S.L.',
#  'OCEAN PRESS PTY LTD.',
#  'OLEOHIDRÁULICA FERRUZ, S.A.',
#  'OLINET INTERNATIONAL, S.A.',
#  'OLIVÉ EXPORTACIONES Y SUMINISTROS, S.L.',
#  'OLIVÉ QUÍMICA, S.A.',
#  'OMMIACREST TRADING, LDA.',
#  'OPELIKA INVESTMENT CORP.',
#  'OPERADORA DE COMERCIO UNIVERSAL, S.A. DE C.V.',
#  'OPERATORI MOVIMENTI TERRA LAGUNARI – O.M.T.L., S.R.L.',
#  'OPTIMAL RECAMBIOS, S.L.',
#  'ORONA, S. COOP.',
#  'ORTIZ ASPIZUA HERMANOS, S.L.',
#  'OSTALMAR, S.A.',
#  'OTTOBOCK DO BRASIL TÉCNICA ORTOPÉDICA LTDA.',
#  'P.A.S.I. PUMPEN UND ARMATUREN SERVIDE INTERNATIONAL GMBH',
#  'P.R. PARTS AND COMPONENTS GMBH',
#  'PAGAZ, S.L.',
#  'PAGIN PREFABBRICATI, S.R.L.',
#  'PAM INTERNATIONAL, N.V.',
#  'PANAVANA INTERNATIONAL TRADING AND SHIPPING INC.',
#  'PANDA INTERNATIONAL INFORMATION TECHNOLOGY CO., LTD.',
#  'PANELECTRA ENTERPRICES, S.A.',
#  'PEGASUS LIMITED, S.A.',
#  'PENTOL ENVIRO UK LTD.',
#  'PENTOL GMBH',
#  'PERFECCIONAMIENTOS TÉCNICOS SALAMANCA, S.L.',
#  'PESCAFINA, S.A.',
#  'PESCANOVA ESPAÑA, S.L.',
#  'PETROPLASTICS & CHEMICALS LIMITED',
#  'PEVISA 1983, S.L.',
#  'PHARM CANADA INC.',
#  'PHOENICIA TRADING (AFRO-ASIA), S.A.L.',
#  'PHYSIOMED ELEKTROMEDIZIN, A.G.',
#  'PIELES SINTÉTICAS, S.A. DE C.V.',
#  'PINTURAS DOAL, S.A. DE C.V.',
#  'PINTURAS GALINDO, S.L.',
#  'PINTURAS HEMPEL, S.A.',
#  'PINTURAS HEMPEL, S.A.U.',
#  'PINTURAS ISAVAL, S.L.',
#  'PINTURAS MACY, S.A.',
#  'PINTURAS MONTO, S.A.',
#  'PINTURAS MONTO, S.A.U.',
#  'PIPEWAY ENGENHARIA LTDA.',
#  'PISCIS INTERNATIONAL COMPANY, S.A.',
#  'PIÑOL SANJAUME, S.L.',
#  'PLEATEX COMPANY INC.',
#  'PLECOSAN, S.L.',
#  'PLUVITEC, S.P.A.',
#  'PLUZ, S.A. DE C.V.',
#  'PLÁSTICOS VIDAL, S.L.',
#  'POLINDUSTRY, S.A.',
#  'POSADA Y MOLINA DE TELECOMUNICACIONES, S.L.',
#  'POSITRONICA, S.A.',
#  'POTEVIO INTERNATIONAL COMPANY LIMITED',
#  'POWER CONSTRUCTION CORPORATION OF CHINA LTD.',
#  'PRAXIS PHARMACEUTICAL, S.A.',
#  'PRECISPORT, S.L.',
#  'PRELEZEC, S.A.',
#  'PREPARADOS ALIMENTICIOS, S.A.',
#  'PRIOR INDUSTRIES AUSTRALIA PTY LTD.',
#  'PRO INTERNATIONAL IMPORT EXPORT INC.',
#  'PRODUCTOS LA CONSTANCIA, S.L.',
#  'PRODUCTOS ROCHE (NICARAGUA), S.A.',
#  'PROMACON ITALIA OFTALMOLOGIA, S.R.L.',
#  'PROMAEL SUMINISTROS ELÉCTRICOS, S.L.',
#  'PROMED INTERNACIONAL, S.L.',
#  'PROMED, S.L.',
#  'PROMOTORA DE ARTÍCULOS, SUMINISTROS Y SERVICIOS, S.A. (PASS, S.A.)',
#  'PROMOTORA LUX, S.A.',
#  'PROMOTORA ORBITA, S.L.',
#  'PROQUIMIA, S.A.',
#  'PROVEEDORA DE ACEROS, S.A. DE C.V.',
#  'PT ARCHIPIELAGO INTERNATIONAL INDONESIA',
#  'PUENTE DE INVERSIONES, S.A.',
#  'PUREZZA DE MEXICO, S.A. DE C.V.',
#  'QATARI RESORTS COMPANY',
#  'QINGDAO HAINERGY TECHNOLOGY CORP., LTD.',
#  'QS ADHESIVES & SEALANTS, S.L.',
#  'QUALITY COURIERS INTERNATIONAL, A.V.V.',
#  'QUANZHOU JIANDA IMPORT & EXPORT TRADE LIMITED COMPANY',
#  'QUICK MANUFACTURING INTERNATIONAL, S.R.L.',
#  'QUIMIPUR, S.L.U.',
#  'QUÍMICAS MERISTEM, S.L.',
#  'QUÍMICAS QUIMXEL, S.L.',
#  'QUÍMICAS SANZ, S.L.',
#  'Quimipur, S.L.U.',
#  'R. & P. COMPANY, S.R.L.',
#  'R.B.S. 92, S.A. DE C.V.',
#  'R.B.S. 92, S.A. de C.V.',
#  'R.F. RIKO FINANCE, S.A.',
#  'RAYTUR CARIBE, S.A.',
#  'RAYTUR CARiBE, S.A.',
#  'REAL CONTROLS, S.R.L.',
#  'REBOCA, S.L.',
#  'RECALVI, S.L.',
#  'REDUCTORES CUÑAT, S.A.',
#  'REDÍN INTERNACIONAL TALDE, S.L',
#  'REFRIGERACIÓN GREDOS, S.L.',
#  'REGISTRO DE NAVEGACIÓN MARÍTIMA DE RUSIA ',
#  'REGOR INC.',
#  'REITER PETROLEUM INC.',
#  'RENOLIT TECNO IMAC, S.R.L.',
#  'RENOVA MOTOR, S.L.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / AMP AUDIO INC.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / AURELIA INTERNATIONAL, S.A.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / BETA MUSIC DI FABRI G & C, S.A.S.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / CORPORACIÓN INTERNACIONAL DE COSMÉTICOS Y PERFUMES, S.A.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / DELTA AIR LINES INC.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / ENDIRECTO, GMBH',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / EURO BUSINESS MARKET, S.L.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / INCSA, S.A.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / INDUSTRIA NACIONAL DE CONFECCIONES, S.A., (INCSA)',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / INGENIERÍA DEL ARTE, 2011, S.L.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / IRE PRODUCTIONS INC.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / NOSTRUM ENTERPRISES, S.A.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / SALINA COMPAÑÍA DE SERVICIOS INTEGRALES, S.L.',
#  'REPRESENTACIONES CULTURALES, S.A. (RECSA) / TROPIX CARIBE, S.L.',
#  'REPRESENTACIONES EMPRESARIALES SHANNON, S.A. DE C.V.',
#  'REPRESENTACIONES JUNIOR LIMITADA',
#  'REPRESENTACIONES JUNIOR LIMITADA CORONADO Y SAQUILMER Y CIA. LTDA.',
#  'REPRESENTACIONES PLATINO, S.A. / AGOSTINI GMBH',
#  'REPRESENTACIONES PLATINO, S.A. / ALLUSI, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / ANTILLANA DE EXPORT OFFICE ESPAÑA, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / ASFALTOS CHOVA, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / AUTOMA, S.R.L.',
#  'REPRESENTACIONES PLATINO, S.A. / BD CARIBE, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / BEYCO UNION, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / BIOAMAZONAS INDUSTRIA E COMERCIO DE MEDICAMENTOS FITOTERAPICOS LTDA.',
#  'REPRESENTACIONES PLATINO, S.A. / BIOCHROM LABORATORIO, C.A.',
#  'REPRESENTACIONES PLATINO, S.A. / BRUGAROLAS, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / CARL ZEISS DE MEXICO, S.A. DE C.V.',
#  'REPRESENTACIONES PLATINO, S.A. / COMERCIAL CARIMEX, S.A. DE C.V.',
#  "REPRESENTACIONES PLATINO, S.A. / COMERCIAL D'ARGONI, S.A.",
#  'REPRESENTACIONES PLATINO, S.A. / COMEX, S.R.L.',
#  'REPRESENTACIONES PLATINO, S.A. / CTT, S.A. de C.V.',
#  'REPRESENTACIONES PLATINO, S.A. / DISTRIBUCIONES EUROPEAS TEXTILES, S.A. (DETSA)',
#  'REPRESENTACIONES PLATINO, S.A. / DISTRIBUCIONES EXCLUSIVAS SERCOIS, S.L.L.',
#  'REPRESENTACIONES PLATINO, S.A. / ECHO EXPORT, S.R.L.',
#  'REPRESENTACIONES PLATINO, S.A. / ELETROFLEX COMERCIAL EXPORTADORA LTDA.',
#  'REPRESENTACIONES PLATINO, S.A. / FIDAS ENTERPRISES INC.',
#  'REPRESENTACIONES PLATINO, S.A. / FOLKSY SHOP WEERT, B.V. (INTRAFOOD)',
#  'REPRESENTACIONES PLATINO, S.A. / FUGRAN COMERCIAL E INDUSTRIAL, S.A. ',
#  'REPRESENTACIONES PLATINO, S.A. / GERMANS BOADA, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / GESTURONA, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / GRUPO CTT, S.A. DE C.V.',
#  'REPRESENTACIONES PLATINO, S.A. / IMPOTRADING INTERNATIONAL INC.',
#  'REPRESENTACIONES PLATINO, S.A. / INTERNA TIONAL SCIENTIFIC ENTERPRISE AND DISTRIBUTION, N.V. (ISED, N.V.)',
#  'REPRESENTACIONES PLATINO, S.A. / J.L.P. ENTERPRISES S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / KERASOL 2000, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / LANTIA MARÍTIMA, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / LATIN MOTORES S.R.L.',
#  'REPRESENTACIONES PLATINO, S.A. / MERZ PHARMA, S.A. DE C.V.',
#  'REPRESENTACIONES PLATINO, S.A. / MERZ PHARMACEUTICALS, GMBH',
#  'REPRESENTACIONES PLATINO, S.A. / MINDMAX MEDICAL SOLUTIONS, S.A.',
#  'REPRESENTACIONES PLATINO, S.A. / PLECOSAN, S.L.',
#  'REPRESENTACIONES PLATINO, S.A. / RIVIÉRE BLANCHE ANSTALT',
#  'REPRESENTACIONES PLATINO, S.A. / RMERZ PHARMACEUTICALS, GMBH',
#  'REPRESENTACIONES PLATINO, S.A. / SAROK CARIBE, S.R.L.',
#  'REPRESENTACIONES PLATINO, S.A. / SUMINISTROS ELECTROMECÁNICOS, S.A. (ELEKSA)',
#  'REPRESENTACIONES PLATINO, S.A. / TECNO IMAC, S.P.A.',
#  'REPRESENTACIONES PLATINO, S.A. / VIRBAC MÉXICO, S.A. DE C.V.',
#  'REPRESENTACIONES PLATINO, S.A. / WORLD TRADE PANAMA, S.A.',
#  'REPRESENTACIONES PLATINO, S.A., / OLINET INTERNATIONAL, S.A.',
#  'REPRESENTACIONES PLATINO, S.A., / PROMOCIONES CARIBE INVESTMENT CORP.',
#  'REPRESENTACIONES PLATINO,S.A. / ECHO EXPORT, S.R.L.',
#  'REPRESENTACIONES UNIDAS CONTINENTALES, S.A. (REUCO, S.A.)',
#  'REPRESENTACIONES WAJAY, S.L.',
#  'REPRESENTACIONES Y DISTRIBUCIONES, S.A. (REYDISA)',
#  'REUVEN INTERNATIONAL LTD.',
#  'REVELL TRADING CORPORATION',
#  'REVIM CARIBE, S.L.',
#  'REYMO EXPORT-IMPORT, S.L.',
#  'RICARDO J. GUELI, S.A.',
#  'RODABIL, S.A.',
#  'RODABIL, S.A.U.',
#  'RODAS PARTICIPATION, S.A.',
#  'ROLLER INDUSTRIAL, S.A.',
#  'ROMEXIM CANADA INC.',
#  'ROMYSEN, S.A.',
#  'RONALD A. CHISHOLM LIMITED',
#  'ROQUETA ORIGEN, S.L.',
#  'ROVIMPEX NOVALEDO, S.R.L.',
#  'ROWEKO, S.L.',
#  'RUSELPROM TRADE LTD.',
#  'RX BRICOLATGES, S.L.',
#  'Registro de Navegación Marítima de Rusia',
#  'S.I.M.E.S. ITALIA, S.R.L.',
#  'S.R.L. CASA DE COMERCIO CTM',
#  'S.S.S.I. INTERNATIONAL INC.',
#  'SAA FÁBRICA DE TRACTORES DE MINSK',
#  'SACI AGRICOLA, S.A.',
#  'SACMI IMOLA, S.C.',
#  'SADIEL, S.R.L.',
#  'SAHE REPRESENTACIONES INTERNACIONALES, S.A.',
#  'SAINT REMY TRADING, S.A.',
#  'SAMBO TRADER INC.',
#  'SAN ISIDRO DE LOS VALLES PORTUGAL, S.A.',
#  'SANDVIK DE MÉXICO, S.A. DE C.V.',
#  'SANOFI-AVENTIS DE PANAMÁ, S.A.',
#  'SANTA ANA, S.A.',
#  'SANY AUTOMOBILE MANUFACTURING CO., LTD.',
#  'SARL SAINT REMY TRADING',
#  'SAROK CARIBE, S.R.L.',
#  'SARTORIUS, A.G.',
#  'SATI GRUPO TEXTIL, S.A.',
#  'SAUNASPORT, S.L.',
#  'SCAFOM CANADA INC.',
#  'SCANCO TECNOLOGIA, S.A.',
#  'SCARBOROUGH TRUCK CENTRE INC.',
#  'SCHENKER ESPAÑA, S.A.',
#  'SCHENKER LOGISTICS, S.A. (SOCIEDAD UNIPERSONAL)',
#  'SCHNEIDER ELECTRIC INDUSTRIES, S.A.S.',
#  'SCPA SARL',
#  'SCPA SIVEX INTERNATIONAL, S.A.S.',
#  'SEABLINC, B.V. (SRL)',
#  'SEFIGROUP, S.R.L.',
#  'SEPPIM CARAIBES, S.A.',
#  'SEPPIM, S.A.S.',
#  'SERCOTEL CUBA, S.L.',
#  'SERENA TRADING INC.',
#  'SERPRO',
#  'SERRA SACOS Y GESTION, S.L.',
#  'SERVICIOS AGROALIMENTARIOS SOCIEDAD COOPERATIVA ANDALUZA',
#  'SER\xadAGROYL SERVICIOS E INFRAESTRUCTURAS, S.L.',
#  'SEVINCO, S.L.',
#  'SGS SOCIETE GENERALE DE SURVEILLANCE, S.A.',
#  'SHANDONG SHANTUI CONSTRUCTION MACHINERY IMPORT & EXPORT CO., LTD.',
#  'SHANDONG WEIFANG RAINBOW CHEMICAL CO., LTD.',
#  'SHANDONG YIKOTO ECONOMIC AND TRADE CO.',
#  'SHANDONG YIKOTO ECONOMIC AND TRADE CO., LTD.',
#  'SHANGHAI INSTITUTE OF MECHANICAL & ELECTRICAL ENGINEERING CO., LTD (SIMEE)',
#  'SHANGHAI KANGNUO INTERNATIONAL TRADE CO., LTD.',
#  'SHENNKER LOGISTICS, S.A. (SOCIEDAD UNIPERSONAL)',
#  'SHENZHEN ETERNAL CO., LTD. ',
#  'SHENZHEN HUAWEI TECHNICAL SERVICE CO., LTD.',
#  'SHENZHEN RUNCH INDUSTRIAL CORPORATION',
#  'SHERRIT INTERNATIONAL (CUBA) OIL AND GAS LIMITED',
#  'SHERRIT INTERNATIONAL INVESTMENTS (CUBA) LIMITED',
#  'SHIN-EI INTERNATIONAL CO., LTD.',
#  'SICOG OIL AND GAS LIMITED',
#  'SIDCO INTERNATIONAL, S.A.',
#  'SILSA DOMINICANA, S.R.L.',
#  'SILVERFIN AIR AND MARITIME DIVISION LTD.',
#  'SIMIL CUERO PLYMOUTH, S.A. DE C.V.',
#  'SIMPLEX CZ SRO',
#  'SINOCHEM GROUP',
#  'SINOTRUK QINGDAO HEAVY INDUSTRY CO., LTD.',
#  'SINTEPLAST, S.A.',
#  'SIPCAM OXON, S.P.A.',
#  'SISTEM COSTRUZIONI, S.R.L.',
#  ...]
